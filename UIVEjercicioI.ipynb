# %% [markdown]
# <a href="https://colab.research.google.com/github/EfrenOlivasITD/PyE/blob/main/UIVEjercicioI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Probabilidad y estadistica**
#
# # Unidad 4. Distribucion normal
#
# Practica 1
#
# Facilitador: Dr. Jose Gabriel Rodriguez Rivas
#
# Alumno: Efren de Jesus Olivas Gomez
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Ejercicio 1
# Una revision de los pesos de  500 estudiantes del itd, evidencio que la media es de 70kg y la desviacione estandar es de 4kg. Suponiendo que los valores se distribuyen normalmente. Hallar lo siguiente:
#
#
# *   Generar aleatoriamente las edades de los 500 estudiantes con una media de 70kg y una desviacion estandar de 4kg.
# *   Realizar un histograma de las edades
#
#
# *   Graficar la funcion de densidad de probabilidad (PDF)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
# Generar datos para la distribucion normal
media = 70 # Media
desv_std = 4 # Desviacion estandar
num_datos = 500

# Generamos los datos de manera aleatoria y los ponemos en una lista (array)
datos = np.random.normal(media, desv_std, num_datos)
datos[0:50] #Mostrar los primeros 50
# Out:
# array([70.51155925, 65.54482213, 66.97423191, 79.62092721, 67.52841141,
#        69.70571249, 67.81614896, 67.20026151, 64.22541058, 71.1579304 ,
#        66.18090509, 62.52237258, 65.03084015, 70.4697143 , 63.61649602,
#        71.30238564, 79.04211629, 64.68760008, 64.021534  , 70.80077314,
#        70.22764792, 69.84701013, 65.00669439, 65.90747145, 65.06329961,
#        66.811545  , 64.88215402, 74.88840911, 73.19164861, 71.58791392,
#        67.18449643, 69.71098298, 65.76142797, 64.73910701, 68.81802018,
#        78.56567638, 71.39888461, 71.22983051, 76.940778  , 67.41215754,
#        68.38770528, 69.1903708 , 62.93014868, 64.95684555, 70.44515015,
#        63.57780813, 76.64069129, 67.19869062, 64.84969223, 69.82029897])

# %%
plt.figure(figsize=(6,4))
plt.hist(datos, bins=15, alpha=0.4, color='b')# Histograma de datos
plt.title('Distribucion Normal')
plt.xlabel('Peso en Kg de los Estudiantes')
plt.grid(True)
plt.show()

# %%
# Crear un rango de valores para crear una densidad
x = np.linspace(media-3*desv_std, media+3*desv_std, num_datos)

# Calcular la PDF de la distribucion normal
pdf = 1/(desv_std * np.sqrt(2 * np.pi)) * np.exp( - (x - media)**2 / (2 * desv_std**2) )

# %%
print("Imprimir los Primeros 50 Valores de x", x[0:50], " y los Primeros 50 Valores de pdf", pdf[0:50])
# Out:
# Imprimir los Primeros 50 Valores de x [58.         58.04809619 58.09619238 58.14428858 58.19238477 58.24048096
#  58.28857715 58.33667335 58.38476954 58.43286573 58.48096192 58.52905812
#  58.57715431 58.6252505  58.67334669 58.72144289 58.76953908 58.81763527
#  58.86573146 58.91382766 58.96192385 59.01002004 59.05811623 59.10621242
#  59.15430862 59.20240481 59.250501   59.29859719 59.34669339 59.39478958
#  59.44288577 59.49098196 59.53907816 59.58717435 59.63527054 59.68336673
#  59.73146293 59.77955912 59.82765531 59.8757515  59.9238477  59.97194389
#  60.02004008 60.06813627 60.11623246 60.16432866 60.21242485 60.26052104
#  60.30861723 60.35671343]  y los Primeros 50 Valores de pdf [0.00110796 0.00114858 0.0011905  0.00123379 0.00127846 0.00132455
#  0.00137211 0.00142118 0.00147178 0.00152397 0.00157777 0.00163325
#  0.00169042 0.00174935 0.00181007 0.00187262 0.00193706 0.00200342
#  0.00207176 0.00214212 0.00221455 0.0022891  0.00236581 0.00244475
# ...

# %%
plt.figure(figsize=(6,4))
plt.plot(x, pdf, label='normal:(media:{}; ds:{})'.format(np.round(media, 2), np.round(desv_std, 2)))
plt.title('Funcion de Densidad de Probabilidad (PDF) - Distribucion Normal')
plt.xlabel('Peso en Kg de los Estudiantes')
plt.ylabel('Densidad de Probabilidad')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Graficar histograma
plt.figure(figsize=(6,4))
plt.hist(datos, bins=15, alpha=0.4, density=True, color='b')
plt.plot( x, pdf, 'k', linewidth=2, )

plt.title('Distribucion Normal')
plt.xlabel('Peso en Kg de los Estudiantes')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Ejercicio 2

# %%
plt.figure(figsize=(6,4))

# Parametros de la distribucion normal
media = 70 #Media
desv_std = 4 #Desviacion estandar
total_estudiantes = 500

# Variable para calculo de la probabilidad de que un estudainte pese menos de 75kg
peso_limite = 79

# Primero necesitamos calcular la probabilidad que un estudainte pese menos
# de 75kg utilizando la funcion de distribucion acumulativa (CDF) de la distribucion normal
prob_menos_75kg = norm.cdf(peso_limite, media, desv_std)

# %%
# Calculo del numero de estudiantesque pesan menos de 75kg
estudiantes_menos_75kg = total_estudiantes * prob_menos_75kg

print("Probabilidad de que un Estudiante Pese Menos de 75kg: ", prob_menos_75kg)
print("Numero de Estudiantes que Pesen Menos de 75kg: ", estudiantes_menos_75kg)

# Graficar la distribucion normal
x = np.linspace(media-4*desv_std, media+4*desv_std, 1000)
y = norm.pdf(x, media, desv_std)

plt.plot(x, y, 'b', linewidth=2)
plt. fill_between(x, y, where=(x <= peso_limite), color='skyblue', alpha=0.5)
plt.title('Probabilidad de que un estudiante pese menos de 75kg. \n $\mu=70$, $\sigma=4$,  x=500')
plt.xlabel('Peso en Kg de los Estudiantes')
plt.ylabel('Densidad de Probabilidad')
plt.grid(True)
plt.show()
# Out:
# Probabilidad de que un Estudiante Pese Menos de 75kg:  0.9877755273449553
# Numero de Estudiantes que Pesen Menos de 75kg:  493.88776367247766

# %%
plt.figure(figsize=(6,4))

#  Parametros dela desviacioon normal
media = 70 #Media
desv_std = 4 #Desviacion estandar
total_estudiantes = 500

# Variable para calculo de la probabilidad de que un estudainte pese menos de 62kg
peso_limite = 62

# Primero necesitamos calcular la probabilidad que un estudainte pese menos
# de 62kg utilizando la funcion de distribucion acumulativa (CDF) de la distribucion normal
prob_menos_62kg = norm.cdf(peso_limite, media, desv_std) # calcula la probabilidad antes de usarla

# Calculo del numero de estudiantes que pesan menos de 62kg
estudiantes_menos_62kg = total_estudiantes * prob_menos_62kg

print  ("Probabilidad de que un Estudiante Pese Menos de 62kg: ", prob_menos_62kg)
print("Numero de Estudiantes que Pesen Menos de 62kg: ", estudiantes_menos_62kg)
# Out:
# Probabilidad de que un Estudiante Pese Menos de 62kg:  0.022750131948179195
# Numero de Estudiantes que Pesen Menos de 62kg:  11.375065974089598
