# %% [markdown]
# <a href="https://colab.research.google.com/github/EfrenOlivasITD/PyE/blob/main/Practica4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Probabilidad y estadistica**
#
# # Unidad 1
#
# # Practica 4. Tablas de frecuencias.
#
# Facilitador: Dr. Jose Gabriel Rodriguez Rivas
#
# Alumno: Efren de Jesus Olivas Gomez
#
# ![image.png](data:image/png;base64,...)

# %%
import random
edades = []
for i in range(100):
  numero_aleatorio = random.randint(18, 70)
  edades.append(numero_aleatorio)
print(edades)
# Out:
# [67, 42, 22, 41, 29, 21, 28, 59, 69, 22, 62, 39, 65, 27, 66, 57, 63, 18, 52, 47, 70, 62, 57, 41, 30, 32, 70, 22, 68, 42, 70, 53, 68, 22, 25, 29, 56, 53, 53, 36, 43, 65, 51, 28, 26, 61, 37, 37, 57, 41, 49, 60, 42, 68, 24, 35, 35, 24, 62, 39, 49, 29, 37, 52, 30, 52, 43, 28, 47, 19, 63, 31, 34, 51, 65, 59, 52, 62, 58, 35, 34, 39, 23, 54, 21, 36, 57, 30, 29, 35, 33, 63, 19, 19, 42, 65, 32, 47, 53, 44]

# %%
import pandas as pd

# %%
df = pd.DataFrame(edades, columns=['Edad'])
df.head()
# Out:
#    Edad
# 0    67
# 1    42
# 2    22
# 3    41
# 4    29

# %%
tabla_frecuencias = df['Edad'].value_counts().reset_index()
tabla_frecuencias.columns = ['Edad', 'Frecuencia']
tabla_frecuencias = tabla_frecuencias.sort_values(by='Edad')

print ("Tabla de Distribucion de Frecuencias: ")
tabla_frecuencias
# Out:
# Tabla de Distribucion de Frecuencias:
#     Edad  Frecuencia
# 39    18           1
# 10    19           3
# 27    21           2
# 8     22           4
# 29    23           1
# 25    24           2
# 38    25           1
# 36    26           1
# 41    27           1
# 9     28           3
# 7     29           4
# 17    30           3
# 28    31           1
# 24    32           2
# 31    33           1
# 22    34           2
# 1     35           4
# 21    36           2
# 11    37           3
# 12    39           3
# 13    41           3
# 6     42           4
# 20    43           2
# 43    44           1
# 15    47           3
# 23    49           2
# 19    51           2
# 2     52           4
# 4     53           4
# 30    54           1
# 37    56           1
# 3     57           4
# 32    58           1
# 26    59           2
# 34    60           1
# 35    61           1
# 5     62           4
# 14    63           3
# 0     65           4
# 40    66           1
# 33    67           1
# 18    68           3
# 42    69           1
# 16    70           3

# %%
tabla_frecuencias['Frec Relativa'] = tabla_frecuencias['Frecuencia'] / 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa
# 39    18           1           0.01
# 10    19           3           0.03
# 27    21           2           0.02
# 8     22           4           0.04
# 29    23           1           0.01
# 25    24           2           0.02
# 38    25           1           0.01
# 36    26           1           0.01
# 41    27           1           0.01
# 9     28           3           0.03
# 7     29           4           0.04
# 17    30           3           0.03
# 28    31           1           0.01
# 24    32           2           0.02
# 31    33           1           0.01
# 22    34           2           0.02
# 1     35           4           0.04
# 21    36           2           0.02
# 11    37           3           0.03
# 12    39           3           0.03
# 13    41           3           0.03
# 6     42           4           0.04
# 20    43           2           0.02
# 43    44           1           0.01
# 15    47           3           0.03
# 23    49           2           0.02
# 19    51           2           0.02
# 2     52           4           0.04
# 4     53           4           0.04
# 30    54           1           0.01
# 37    56           1           0.01
# 3     57           4           0.04
# 32    58           1           0.01
# 26    59           2           0.02
# 34    60           1           0.01
# 35    61           1           0.01
# 5     62           4           0.04
# 14    63           3           0.03
# 0     65           4           0.04
# 40    66           1           0.01
# 33    67           1           0.01
# 18    68           3           0.03
# 42    69           1           0.01
# 16    70           3           0.03

# %%
tabla_frecuencias['Frec Porcentual'] = tabla_frecuencias['Frecuencia'] / 100 * 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual
# 39    18           1           0.01              1.0
# 10    19           3           0.03              3.0
# 27    21           2           0.02              2.0
# 8     22           4           0.04              4.0
# 29    23           1           0.01              1.0
# 25    24           2           0.02              2.0
# 38    25           1           0.01              1.0
# 36    26           1           0.01              1.0
# 41    27           1           0.01              1.0
# 9     28           3           0.03              3.0
# 7     29           4           0.04              4.0
# 17    30           3           0.03              3.0
# 28    31           1           0.01              1.0
# 24    32           2           0.02              2.0
# 31    33           1           0.01              1.0
# 22    34           2           0.02              2.0
# 1     35           4           0.04              4.0
# 21    36           2           0.02              2.0
# 11    37           3           0.03              3.0
# 12    39           3           0.03              3.0
# 13    41           3           0.03              3.0
# 6     42           4           0.04              4.0
# 20    43           2           0.02              2.0
# 43    44           1           0.01              1.0
# 15    47           3           0.03              3.0
# 23    49           2           0.02              2.0
# 19    51           2           0.02              2.0
# 2     52           4           0.04              4.0
# 4     53           4           0.04              4.0
# 30    54           1           0.01              1.0
# 37    56           1           0.01              1.0
# 3     57           4           0.04              4.0
# 32    58           1           0.01              1.0
# 26    59           2           0.02              2.0
# 34    60           1           0.01              1.0
# 35    61           1           0.01              1.0
# 5     62           4           0.04              4.0
# 14    63           3           0.03              3.0
# 0     65           4           0.04              4.0
# 40    66           1           0.01              1.0
# 33    67           1           0.01              1.0
# 18    68           3           0.03              3.0
# 42    69           1           0.01              1.0
# 16    70           3           0.03              3.0

# %%
tabla_frecuencias['Frec Acumulada'] = tabla_frecuencias['Frecuencia'].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual  Frec Acumulada
# 39    18           1           0.01              1.0               1
# 10    19           3           0.03              3.0               4
# 27    21           2           0.02              2.0               6
# 8     22           4           0.04              4.0              10
# 29    23           1           0.01              1.0              11
# 25    24           2           0.02              2.0              13
# 38    25           1           0.01              1.0              14
# 36    26           1           0.01              1.0              15
# 41    27           1           0.01              1.0              16
# 9     28           3           0.03              3.0              19
# 7     29           4           0.04              4.0              23
# 17    30           3           0.03              3.0              26
# 28    31           1           0.01              1.0              27
# 24    32           2           0.02              2.0              29
# 31    33           1           0.01              1.0              30
# 22    34           2           0.02              2.0              32
# 1     35           4           0.04              4.0              36
# 21    36           2           0.02              2.0              38
# 11    37           3           0.03              3.0              41
# 12    39           3           0.03              3.0              44
# 13    41           3           0.03              3.0              47
# 6     42           4           0.04              4.0              51
# 20    43           2           0.02              2.0              53
# 43    44           1           0.01              1.0              54
# 15    47           3           0.03              3.0              57
# 23    49           2           0.02              2.0              59
# 19    51           2           0.02              2.0              61
# 2     52           4           0.04              4.0              65
# 4     53           4           0.04              4.0              69
# 30    54           1           0.01              1.0              70
# 37    56           1           0.01              1.0              71
# 3     57           4           0.04              4.0              75
# 32    58           1           0.01              1.0              76
# 26    59           2           0.02              2.0              78
# 34    60           1           0.01              1.0              79
# 35    61           1           0.01              1.0              80
# 5     62           4           0.04              4.0              84
# 14    63           3           0.03              3.0              87
# 0     65           4           0.04              4.0              91
# 40    66           1           0.01              1.0              92
# 33    67           1           0.01              1.0              93
# 18    68           3           0.03              3.0              96
# 42    69           1           0.01              1.0              97
# 16    70           3           0.03              3.0             100

# %% [markdown]
# # Regla de sturges
# c = 1 +log2 (N)
#
# donde N es el tamaño de la muestra

# %%
import math

# %%
print (edades)
# Out:
# [67, 42, 22, 41, 29, 21, 28, 59, 69, 22, 62, 39, 65, 27, 66, 57, 63, 18, 52, 47, 70, 62, 57, 41, 30, 32, 70, 22, 68, 42, 70, 53, 68, 22, 25, 29, 56, 53, 53, 36, 43, 65, 51, 28, 26, 61, 37, 37, 57, 41, 49, 60, 42, 68, 24, 35, 35, 24, 62, 39, 49, 29, 37, 52, 30, 52, 43, 28, 47, 19, 63, 31, 34, 51, 65, 59, 52, 62, 58, 35, 34, 39, 23, 54, 21, 36, 57, 30, 29, 35, 33, 63, 19, 19, 42, 65, 32, 47, 53, 44]

# %%
df = pd.DataFrame({'Edad': edades})
df
# Out:
#     Edad
# 0     67
# 1     42
# 2     22
# 3     41
# 4     29
# ..   ...
# 95    65
# 96    32
# 97    47
# 98    53
# 99    44
#
# [100 rows x 1 columns]

# %%
n = len(edades)
K = int(1 + math.log2(100))
print ("Valor de n = ", n , "\nNumero de intervalos =", K)
# Out:
# Valor de n =  100
# Numero de intervalos = 7

# %%
tabla_frecuencias = pd.cut(df['Edad'], bins=K, include_lowest=True).value_counts().reset_index()
tabla_frecuencias.columns = ['Clase', 'Frec']
tabla_frecuencias
# Out:
#               Clase  Frec
# 0    (62.571, 70.0]    16
# 1  (25.429, 32.857]    15
# 2  (32.857, 40.286]    15
# 3  (17.947, 25.429]    14
# 4  (55.143, 62.571]    14
# 5  (40.286, 47.714]    13
# 6  (47.714, 55.143]    13

# %%
tabla_frecuencias = tabla_frecuencias.sort_values(by='Clase')
tabla_frecuencias
# Out:
#               Clase  Frec
# 3  (17.947, 25.429]    14
# 1  (25.429, 32.857]    15
# 2  (32.857, 40.286]    15
# 5  (40.286, 47.714]    13
# 6  (47.714, 55.143]    13
# 4  (55.143, 62.571]    14
# 0    (62.571, 70.0]    16

# %%
tabla_frecuencias['Frec Rel'] = tabla_frecuencias['Frec'] / n
tabla_frecuencias['Frec Porc'] = tabla_frecuencias['Frec'] / n * 100
tabla_frecuencias['Frec Ac'] = tabla_frecuencias['Frec'].cumsum()
tabla_frecuencias['Frec Rel Ac'] = tabla_frecuencias['Frec Rel'].cumsum()
tabla_frecuencias['Frec Porc Arc']= tabla_frecuencias['Frec Porc'].cumsum()

print (tabla_frecuencias)

# %%
import matplotlib.pyplot as plt
plt.hist(edades, alpha = 0.5, bins = 20)
plt.title("Histograma de edades basado en la funcion matplotib con valores estandar")
# Out:
# Text(0.5, 1.0, 'Histograma de edades basado en la funcion matplotib con valores estandar')

# %%
import matplotlib.pyplot as plt
plt.hist(df['Edad'], bins = K, alpha = 0.5)
plt.title("Histograma de edades basado en la regla de Sturges")
plt.ylabel('Frecuencia')
plt.xlabel('Edades')
# Out:
# Text(0.5, 0, 'Edades')

# %% [markdown]
# # Practica 5
# ## Diagramas de cajas y bigotes
# 1.Las lineas se uan para indicar la variabilidad de los cuartiles superior e inferior

# %%
edades2 = []
for i in range(100):
  numero_aleatorio = random.randint(18, 87)
  edades2.append(numero_aleatorio)
print(edades2)
# Out:
# [36, 77, 51, 49, 63, 39, 33, 62, 85, 35, 43, 83, 55, 80, 28, 20, 19, 43, 59, 55, 29, 85, 41, 58, 59, 21, 39, 20, 75, 82, 74, 54, 49, 85, 52, 29, 38, 63, 61, 21, 83, 76, 61, 71, 55, 77, 51, 58, 35, 78, 38, 32, 64, 86, 26, 33, 38, 57, 85, 73, 37, 46, 58, 45, 26, 71, 82, 20, 30, 49, 81, 71, 26, 59, 56, 55, 64, 73, 34, 38, 42, 28, 61, 56, 60, 42, 37, 71, 31, 53, 52, 23, 59, 40, 41, 74, 27, 41, 51, 52]

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))
bplot1 = ax1.boxplot(edades,
                     vert=True,   #Vertical box aligment
                     patch_artist=True)   #Fill with color
ax1.set_title('Edades encuesta 1')
bplot2 = ax2.boxplot(edades2,
                     vert=True,   #Vertical box aligment
                     patch_artist=True)   #Fill with color
ax2.set_title('Edades encuesta 2')
plt.show()

# %%
#Agregar una edad mas a la lista de edades 2
edades2.append(130)

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))
bplot1 = ax1.boxplot(edades,
                     vert=True,   #Vertical box aligment
                     patch_artist=True)   #Fill with color
ax1.set_title('Edades encuesta 1')
bplot2 = ax2.boxplot(edades2,
                     vert=True,   #Vertical box aligment
                     patch_artist=True)   #Fill with color
ax2.set_title('Edades encuesta 2')
plt.show()
