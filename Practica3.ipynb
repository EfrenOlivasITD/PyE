# %% [markdown]
# <a href="https://colab.research.google.com/github/EfrenOlivasITD/PyE/blob/main/Practica3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Probabilidad y estadistica**
#
# # Unidad 1
#
# # Practica 3. Maximo, minimo, rango y dispersion de datos.
#
# Facilitador: Dr. Jose Gabriel Rodriguez Rivas
#
# Alumno: Efren de Jesus Olivas Gomez
#
# ![image.png](data:image/png;base64,...)

# %%
import random
import matplotlib.pyplot as plt
from statistics import *

# %%
fabrica1 = []
for i in range(100):
  numero_aleatorio = round(random.uniform(50, 100), 2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [72.19, 94.82, 66.63, 97.05, 68.02, 93.87, 94.89, 79.23, 89.01, 59.61, 94.37, 74.01, 63.71, 61.65, 68.24, 73.73, 92.73, 75.85, 70.44, 63.75, 62.44, 80.6, 87.91, 56.62, 58.65, 89.88, 67.27, 66.12, 86.33, 77.13, 64.63, 54.64, 93.68, 59.02, 58.27, 67.22, 69.78, 78.65, 51.04, 91.33, 90.32, 91.81, 92.23, 66.43, 60.81, 50.82, 66.9, 84.67, 80.91, 93.38, 92.7, 77.15, 67.61, 61.76, 88.97, 50.9, 63.57, 70.71, 74.36, 52.01, 99.81, 87.26, 66.52, 59.09, 62.93, 71.05, 60.61, 53.3, 96.72, 58.29, 78.78, 92.54, 88.02, 92.29, 74.76, 54.53, 68.45, 92.23, 76.45, 67.72, 95.89, 96.64, 68.79, 91.59, 76.44, 52.32, 57.22, 93.63, 56.36, 81.7, 55.68, 51.55, 64.6, 75.78, 78.05, 52.05, 62.95, 88.05, 72.67, 55.5]

# %%
fabrica2 = []
for i in range(100):
  numero_aleatorio = round( random.uniform(50, 100), 2)
  fabrica2.append(numero_aleatorio)
print (fabrica2)
# Out:
# [63.55, 65.47, 72.81, 75.56, 95.83, 69.83, 80.11, 72.71, 70.32, 73.13, 73.8, 88.62, 64.42, 51.64, 99.1, 98.92, 56.65, 56.34, 75.45, 72.93, 90.19, 70.78, 58.45, 77.14, 82.09, 58.87, 90.3, 53.54, 92.08, 69.69, 69.43, 91.25, 88.46, 77.29, 80.38, 64.29, 83.35, 73.1, 89.83, 79.82, 64.21, 75.13, 87.33, 80.1, 58.91, 71.58, 99.77, 62.69, 59.76, 69.75, 82.89, 76.49, 80.5, 78.27, 54.42, 52.19, 55.3, 77.81, 58.5, 88.39, 89.4, 54.62, 99.68, 76.02, 57.94, 86.49, 75.49, 58.23, 52.1, 79.58, 86.39, 50.65, 96.73, 95.67, 77.03, 60.44, 95.51, 75.92, 72.02, 73.41, 69.75, 65.13, 60.06, 52.74, 77.91, 96.46, 76.42, 89.21, 72.26, 54.79, 52.58, 76.38, 99.22, 81.91, 71.03, 59.04, 51.44, 83.01, 70.59, 79.79]

# %%
maximo1 = max(fabrica1)
minimo1 = min(fabrica1)
rango1 = maximo1 - minimo1
media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)

print ( "Estadistica descriptiva de la fabrica 1 \n", "Media =", media1,
       "\n Mediana =", mediana1, "\n Moda =", moda1, "\n Maximo =", maximo1,
        "\n Minimo =", minimo1, "\n Rango =", rango1)
# Out:
# Estadistica descriptiva de la fabrica 1
#  Media = 73.8184
#  Mediana = 71.62
#  Moda = 92.23
#  Maximo = 99.81
#  Minimo = 50.82
#  Rango = 48.99

# %%
maximo2 = max(fabrica2)
minimo2 = min(fabrica2)
rango2 = maximo2 - minimo2
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)

print ( "Estadistica descriptiva de la fabrica 1 \n", "Media =", media2,
       "\n Mediana =", mediana2, "\n Moda =", moda2, "\n Maximo =", maximo2,
        "\n Minimo =", minimo2, "\n Rango =", rango2)
# Out:
# Estadistica descriptiva de la fabrica 1
#  Media = 74.0455
#  Mediana = 74.465
#  Moda = 69.75
#  Maximo = 99.77
#  Minimo = 50.65
#  Rango = 49.12

# %% [markdown]
# # Dispersion de los datos

# %%
desviacion_estandar_fabrica1 = stdev(fabrica1)
print (desviacion_estandar_fabrica1)
# Out:
# 14.430165074620875

# %%
desviacion_estandar_fabrica2 = stdev(fabrica2)
print (desviacion_estandar_fabrica2)
# Out:
# 13.624905328185594

# %%
plt.figure(figsize = (8,6))
plt.hist (fabrica1, bins = 10 , alpha = 0.2, color = 'b', edgecolor = "black")
plt.axvline (media1, color = 'b', linestyle = 'dashed', linewidth = 2, label = f'Media = {media1:.2f}')
plt.axvline (mediana1, color = 'r', linestyle = 'dashed', linewidth = 2, label = f'Mediana = {mediana1:.2f}')
plt.axvline (moda1, color = 'y', linestyle = 'dashed', linewidth = 2, label = f'Moda = {moda1:.2f}')
plt.axvline (media1 - desviacion_estandar_fabrica1, color = "black",  linestyle = 'dashed',
             linewidth = 2, label = f'Desv. Estandar = {desviacion_estandar_fabrica1:.2f}')
plt.axvline (media1 + desviacion_estandar_fabrica1, color = "black",  linestyle = 'dashed',
             linewidth = 2)
plt.xlabel ('Valor')
plt.ylabel ('Frecuencia')
plt.title ('Produccion Diaria de la Fabrica 1')
plt.legend ()
plt.show ()

# %%
plt.figure(figsize = (8,6))
plt.hist (fabrica2, bins = 10 , alpha = 0.2, color = 'b', edgecolor = "black")
plt.axvline (media2, color = 'b', linestyle = 'dashed', linewidth = 2, label = f'Media = {media1:.2f}')
plt.axvline (mediana2, color = 'r', linestyle = 'dashed', linewidth = 2, label = f'Mediana = {mediana1:.2f}')
plt.axvline (moda2, color = 'y', linestyle = 'dashed', linewidth = 2, label = f'Moda = {moda1:.2f}')
plt.axvline (media2 - desviacion_estandar_fabrica2, color = "black",  linestyle = 'dashed',
             linewidth = 2, label = f'Desv. Estandar = {desviacion_estandar_fabrica2:.2f}')
plt.axvline (media2 + desviacion_estandar_fabrica2, color = "black",  linestyle = 'dashed',
             linewidth = 2)
plt.xlabel ('Valor')
plt.ylabel ('Frecuencia')
plt.title ('Produccion Diaria de la Fabrica 2')
plt.legend ()
plt.show ()

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt
sns.histplot(x=fabrica1, kde=True, kde_kws={'bw_adjust': 0.5}, bins=10)
plt.show()
