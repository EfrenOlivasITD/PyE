# %% [markdown]
# <a href="https://colab.research.google.com/github/EfrenOlivasITD/PyE/blob/main/Practica1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Probabilidad y estadistica**
#
# # Unidad 1
#
# Practica 1. Estadistica descriptiva basica e histogramas
#
# Facilitador: Dr. Jose Gabriel Rodriguez Rivas
#
# Alumno: Efren de Jesus Olivas Gomez
#
# ![image.png](data:image/png;base64,...)

# %%
from statistics import *

# %% [markdown]
# Ejemplo 1: Registro de calificaciones de 12 alumnos

# %%
#Lista de calificaciones del grupo A de probabilidad y estadistica
grupoa = [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]
print (grupoa)

# %%
#La funcion type nos devuelve el tipo de dato de la variable
type (grupoa)

# %%
#Sacar la media de las calificaciones con una formula
promedio =  sum(grupoa)/len(grupoa)
print (promedio)

# %%
promedio2 = mean(grupoa)
print (promedio2)

# %%
#Determinar el valor de la mediana con la funcion median
mediana = median(grupoa)
print (mediana)

# %%
#Determinar el valor de la moda con la funcion mode
moda = mode(grupoa)
print (moda)

# %%
#En caso de que existan mas de una moda,
moda2 = multimode(grupoa)
print (moda2)

# %% [markdown]
# CORREDORES(PROMEDIO, MODA Y MEDIANA)

# %%
#Definimos una variable llamada tiempos100mts
#Tiempos que tardaron los 10 alumnos
tiempos100mts = [15.10, 17.20, 14.69, 13.27, 22.15, 18.71, 19.15, 20.65, 15.10, 17.20]
#Desplegamos los valores de la lista
print (tiempos100mts)

# %%
#Usamos la funcion mean para determinar el tiempo promedio de la lista de valores
print ("El tiempo promedio de los corredores es =>", mean(tiempos100mts))

# %%
mediana = median(tiempos100mts)
print ("El tiempo mediano de los corredores es =>", mediana)

# %%
moda = mode(tiempos100mts)
print ("La moda de los corredores es =>", moda)

# %%
multimodas = multimode(tiempos100mts)
print ("Las modas de los corredores son =>", multimodas)

# %% [markdown]
# Ejemplo 3: produccion diaria de una fabica

# %%
# Libreria para generar numeros aleatorios
import random

# %%
fabrica1 = []
for i in range(100):
  numero_aleatorio = round( random.uniform(50, 100), 2)
  fabrica1.append(numero_aleatorio)
print (fabrica1)

# %%
fabrica2 = []
for i in range(100):
  numero_aleatorio = round( random.uniform(50, 100), 2)
  fabrica2.append(numero_aleatorio)
print (fabrica2)

# %%
# Libreria de python para graficar valores
import matplotlib.pyplot as plt

# %%
plt.hist(fabrica1)
plt.title("Produccion diaria de la fabrica 1")
# Out:
# Text(0.5, 1.0, 'Produccion diaria de la fabrica 1')

# %%
plt.hist(fabrica2)
plt.title("Produccion diaria de la fabrica 2")
# Out:
# Text(0.5, 1.0, 'Produccion diaria de la fabrica 2')

# %%
media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)
print ("Valores de la fabrica 1")
print ("La media de la fabrica 1 es =>", media1)
print ("La mediana de la fabrica 1 es =>", mediana1)
print ("La moda de la fabrica 1 es =>", moda1)
# Out:
# Valores de la fabrica 1
# La media de la fabrica 1 es => 74.7133
# La mediana de la fabrica 1 es => 74.295
# La moda de la fabrica 1 es => 59.77

# %%
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)
print ("Valores de la fabrica 1")
print ("La media de la fabrica 1 es =>", media2)
print ("La mediana de la fabrica 1 es =>", mediana2)
print ("La moda de la fabrica 1 es =>", moda2)
# Out:
# alores de la fabrica 1
# La media de la fabrica 1 es => 76.1741
# La mediana de la fabrica 1 es => 76.91499999999999
# La moda de la fabrica 1 es => 63.52

# %%
#Generar 2 sublot de 1 renglon por 2 columnas para desplegar los 2 histogramas,
# una a lada de la otra

fig, (ax1, ax2) = plt.subplots(nrows = 1, ncols = 2, figsize=(10,5))
ax1.hist(fabrica1)
ax1.set_title("Produccion diaria de la fabrica 1")
ax2.hist(fabrica2)
ax2.set_title("Produccion diaria de la fabrica 2")
plt.show()

# %%
plt.hist(fabrica1, bins = 10, alpha = 0.2, color = 'b', edgecolor = 'black')
plt.axvline(media1, color = 'b', linestyle = 'dashed', linewidth = 2, label = 'Media')
plt.axvline(mediana1, color = 'r', linestyle = 'dashed', linewidth = 2, label = 'Mediana')
plt.axvline(moda1, color = 'y', linestyle = 'dashed', linewidth = 2, label = 'Moda')
plt.xlabel('valor')
plt.ylabel('frecuencia')
plt.title('Produccion diaria de la fabrica 1')
plt.legend()
plt.show()

# %%
plt.hist(fabrica2, bins = 10, alpha = 0.2, color = 'b', edgecolor = 'black')
plt.axvline(media2, color = 'b', linestyle = 'dashed', linewidth = 2, label = 'Media')
plt.axvline(mediana2, color = 'r', linestyle = 'dashed', linewidth = 2, label = 'Mediana')
plt.axvline(moda2, color = 'y', linestyle = 'dashed', linewidth = 2, label = 'Moda')
plt.xlabel('valor')
plt.ylabel('frecuencia')
plt.title('Produccion diaria de la fabrica 2')
plt.legend()
plt.show()
